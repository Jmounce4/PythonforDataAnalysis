# %%
import numpy as np
import pandas as pd
from scipy import stats

# Create a dataset
data = [10, 15, 20, 25, 30, 30, 30, 35, 40, 45, 50]

# Calculate Mean
mean = np.mean(data)
print(f'Mean: {mean}')

# Calculate Median
median = np.median(data)
print(f'Median: {median}')

# Calculate Mode
mode = stats.mode(data)
print(f'Mode: {mode}, Count: {mode.count}')
# Out:
# Mean: 30.0
# Median: 30.0
# Mode: ModeResult(mode=30, count=3), Count: 3

# %%
range_val = np.ptp(data)
print(f'Range: {range_val}')

# Calculate Variance
variance = np.var(data)
print(f'Variance: {variance}')

# Calculate Standard Deviation
std_deviation = np.std(data)
print(f'Standard Deviation: {std_deviation}')
# Out:
# Range: 40
# Variance: 136.36363636363637
# Standard Deviation: 11.677484162422845

# %%
import matplotlib.pyplot as plt

# Plot Histogram
plt.hist(data, bins=10, alpha=0.75, color='blue', edgecolor='black')
plt.title('Histogram of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# Plot Box Plot
plt.boxplot(data)
plt.title('Box Plot of Data')
plt.ylabel('Value')
plt.show()
